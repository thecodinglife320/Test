// %%
val int1 = 3465
val int2 = -7896

// %%
"%8o"
"%-8o"
"%08o"
"%x".format(int1)
"%X".format(int1)
"%#x".format(int1)
"%#X".format(int1)
// Out:
// 0XD89

// %%
val double1 = 1234.5678
val double2 = -1234.5678

"%f".format(double1)
"% f".format(double1)
"%(f".format(double2)
//"%+f".format(double1)
//"%,f".format(double2)
//"%-15f".format(double1)
//"%15f".format(double1)
//"%015f".format(double1)
//"%15.2f".format(double1)
//"%.3f".format(double2)
//"%.6f".format(double2)
// Out:
// (1234.567800)

// %%
val boolean = true

"%b".format(boolean)
"%B".format(boolean)
// Out:
// TRUE
