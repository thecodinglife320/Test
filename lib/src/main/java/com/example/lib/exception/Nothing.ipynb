// %%
import java.io.FileReader

try {
    FileReader("./res/file.txt").use { fileReader ->
        fileReader.readText().also(::println)
        throw RuntimeException("abc")
    }
}catch(e: RuntimeException){
    println("loi: "+e.message)
}
// Out:
// Kotlin
// Java
// Go
// C++
// C#
// loi: abc

// %%
fun fail(): Nothing = throw RuntimeException("This function always throws an exception")

fun calculatePercentage(marks: Int, total: Int) =
    if (total == 0) fail()
    else (marks / total.toFloat()) * 100

calculatePercentage(20,100)
// Out:
// 20.0

// %%
// Inside if-else condition
val x = if (1>0) {
     TODO("Not decided what to do yet")
} else {
    ""
}
x
// Out:
// kotlin.NotImplementedError: An operation is not implemented: Not decided what to do yet
// 	at Line_13_jupyter.<init>(Line_13.jupyter.kts:3) at Cell In[11], line 3
// 	at java.base/jdk.internal.reflect.DirectConstructorHandleAccessor.newInstance(Unknown Source)
// 	at java.base/java.lang.reflect.Constructor.newInstanceWithCaller(Unknown Source)
// 	at java.base/java.lang.reflect.Constructor.newInstance(Unknown Source)
// 	at kotlin.script.experimental.jvm.BasicJvmScriptEvaluator.evalWithConfigAndOtherScriptsResults(BasicJvmScriptEvaluator.kt:122)
// 	at kotlin.script.experimental.jvm.BasicJvmScriptEvaluator.invoke$suspendImpl(BasicJvmScriptEvaluator.kt:48)
// 	at kotlin.script.experimental.jvm.BasicJvmScriptEvaluator.invoke(BasicJvmScriptEvaluator.kt)
// 	at kotlin.script.experimental.jvm.BasicJvmReplEvaluator.eval(BasicJvmReplEvaluator.kt:49)
// ...

// %%
// Inside a loop
for (item in listOf<String>("")) {
    TODO("Processing of the list items is not implemented yet")
}
// Out:
// kotlin.NotImplementedError: An operation is not implemented: Processing of the list items is not implemented yet
// 	at Line_15_jupyter.<init>(Line_15.jupyter.kts:3) at Cell In[13], line 3
// 	at java.base/jdk.internal.reflect.DirectConstructorHandleAccessor.newInstance(Unknown Source)
// 	at java.base/java.lang.reflect.Constructor.newInstanceWithCaller(Unknown Source)
// 	at java.base/java.lang.reflect.Constructor.newInstance(Unknown Source)
// 	at kotlin.script.experimental.jvm.BasicJvmScriptEvaluator.evalWithConfigAndOtherScriptsResults(BasicJvmScriptEvaluator.kt:122)
// 	at kotlin.script.experimental.jvm.BasicJvmScriptEvaluator.invoke$suspendImpl(BasicJvmScriptEvaluator.kt:48)
// 	at kotlin.script.experimental.jvm.BasicJvmScriptEvaluator.invoke(BasicJvmScriptEvaluator.kt)
// 	at kotlin.script.experimental.jvm.BasicJvmReplEvaluator.eval(BasicJvmReplEvaluator.kt:49)
// ...
